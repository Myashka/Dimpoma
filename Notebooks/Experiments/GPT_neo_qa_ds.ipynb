# %% [markdown]
# # Общая информация
# __Цель:__ сделать fine-tuning GPT neo с 1,2B параметров
#
# __Задачи:__
# 1) Использовать deepspeed
#
# 2) Проверить data collactor

# %% [markdown]
# # Импорт библиотек

# %%
# from google.colab import drive

# drive.mount("/content/drive")

# %%
#!pip install transformers

# %%
import pickle
import warnings

import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, random_split
from tqdm import tqdm
from transformers import (AutoModelForCausalLM, AutoTokenizer,
                          IntervalStrategy, Trainer, TrainingArguments)

warnings.filterwarnings("ignore")

# %%
#!pip install pynvml

# %%
from pynvml import *


def print_gpu_utilization():
    nvmlInit()
    handle = nvmlDeviceGetHandleByIndex(0)
    info = nvmlDeviceGetMemoryInfo(handle)
    print(f"GPU memory occupied: {info.used//1024**2} MB.")

# %%
print_gpu_utilization()
# Out:
# GPU memory occupied: 5809 MB.

# %%
# зафиксируем random seed
torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# # Чтение данных

# %%
# df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/vkr_data/filtered_df.csv")

# %%
pd.set_option("display.max_colwidth", None)

# %%
pd.set_option("display.max_colwidth", None)
with open(f"../../data/prepared/filtered_df.p", "rb") as f:
    df = pickle.load(f)

# %% [markdown]
# Отсортируем датасет по времени и разобьем его на train test

# %%
df = df.sort_values("Q_Date")

# %%
df = df.loc[df.apply(lambda x: f"python" in x.Tag, axis=1)]

# %%
train_df, test_df = np.split(df, [int(0.85 * len(df))])

# %% [markdown]
# # Загрузим модель

# %%
device = torch.device("cuda") if torch.cuda.is_available else "cpu"

# %%
model_name = "EleutherAI/gpt-neo-1.3B"

# %%
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    bos_token="<|startoftext|>",
    eos_token="<|endoftext|>",
    pad_token="<|pad|>",
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████| 4.95G/4.95G [03:14<00:00, 27.3MB/s]

# %%
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(50259, 2048)

# %%
print_gpu_utilization()
# Out:
# GPU memory occupied: 6486 MB.

# %%
questions = df.Q_Body
max_length = max([len(tokenizer.encode(question)) for question in questions])
print(f"Max length: {max_length}")
# Out:
# Max length: 1055

# %%
class Q_A_Dataset(Dataset):
    def __init__(self, df, tokenizer, max_length, tag):
        df = df.loc[df.apply(lambda x: f"{tag}" in x.Tag, axis=1)]
        self.input_ids = []
        self.attn_masks = []
        self.labels = []

        self.answers = []
        self.questions = []

        for _, row in df.iterrows():
            prep_text = f"<|startoftext|>Question: {row.Q_Body}\nAnswer: {row.A_Body}<|endoftext|>"

            question_len = len(
                tokenizer(
                    f"<|startoftext|>Question: {row.Q_Body}\nAnswer:",
                )["input_ids"]
            )

            encoding_dict = tokenizer(
                prep_text, truncation=True, max_length=max_length, padding="max_length"
            )

            self.input_ids.append(torch.tensor(encoding_dict["input_ids"]))
            self.attn_masks.append(torch.tensor(encoding_dict["attention_mask"]))
            self.labels.append(torch.tensor(encoding_dict["input_ids"]))
            self.labels[-1][:question_len] = -100

            self.answers.append(row.A_Body)
            self.questions.append(row.Q_Body)

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return (
            self.input_ids[idx],
            self.attn_masks[idx],
            self.labels[idx],
            self.answers[idx],
            self.questions[idx],
        )

# %%
train_dataset = Q_A_Dataset(train_df, tokenizer, max_length=max_length, tag="python")
test_dataset = Q_A_Dataset(test_df, tokenizer, max_length=max_length, tag="python")

# %%
del df, train_df, test_df

# %% [markdown]
# # Авторизумеся в wandb

# %%
#!pip install wandb

# %%
import wandb

wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\user/.netrc
# True

# %%
run = wandb.init(project="QA specific domain", entity="myashka")
# Out:
# wandb: Currently logged in as: myashka. Use `wandb login --relogin` to force relogin
# wandb version 0.13.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.1
# Run data is saved locally in <code>D:\GorbatovskiAlexey\Study\Diploma\Notebooks\Experiments\wandb\run-20221003_155125-129dk2zk</code>
# Syncing run <strong><a href="https://wandb.ai/myashka/QA%20specific%20domain/runs/129dk2zk" target="_blank">spring-shadow-11</a></strong> to <a href="https://wandb.ai/myashka/QA%20specific%20domain" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# %env WANDB_LOG_MODEL=true
# Out:
# env: WANDB_LOG_MODEL=true

# %%
# %env WANDB_WATCH=all
# %env WANDB_SILENT=true
# Out:
# env: WANDB_WATCH=all
# env: WANDB_SILENT=true

# %% [markdown]
# # Определим Trainer и запустим обучение

# %% [markdown]
# ## Определим DeepSpeed

# %%
# %%bash
# cat <<'EOT' > ds_config_zero3.json
# {
#     "fp16": {
#         "enabled": true,
#         "min_loss_scale": 1,
#         "opt_level": "O2"
#     },
#
#     "optimizer": {
#         "type": "AdamW",
#         "params": {
#             "lr": 5e-05,
#             "betas": [
#             0.9,
#             0.999
#             ],
#             "eps": 1e-8
#         }
#     },
#
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 5e-05,
#             "warmup_num_steps": 100
#         }
#     },
#
#     "zero_optimization": {
#         "stage": 2,
#         "offload_optimizer": {
#             "device": "cpu"
#         },
#         "offload_param": {
#             "device": "cpu"
#         },
#         "allgather_partitions": true,
#         "allgather_bucket_size": 5e8,
#         "contiguous_gradients": true
#     }
# }
# EOT

# %%
import os

os.environ["MASTER_ADDR"] = "localhost"
os.environ["MASTER_PORT"] = "9994"  # modify if RuntimeError: Address already in use
os.environ["RANK"] = "0"
os.environ["LOCAL_RANK"] = "0"
os.environ["WORLD_SIZE"] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# model.config.use_cache = False

# %%
args = TrainingArguments(
    output_dir="/content/drive/MyDrive/Colab Notebooks/vkr_data/results",
    num_train_epochs=5,
    logging_steps=100,
    load_best_model_at_end=True,
    save_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=100,
    weight_decay=0.01,
    logging_dir="/content/drive/MyDrive/Colab Notebooks/vkr_data/logs",
    report_to="wandb",  # enable logging to W&B
    run_name="gpt_neo_second_run",
    evaluation_strategy="epoch",
    fp16=True,
    deepspeed="ds_config_zero3.json",
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    data_collator=lambda data: {
        "input_ids": torch.stack([f[0] for f in data]),
        "attention_mask": torch.stack([f[1] for f in data]),
        "labels": torch.stack([f[0] for f in data]),
    },
)
# Out:
# Using cuda_amp half precision backend

# %%
print_gpu_utilization()
# Out:
# GPU memory occupied: 6314 MB.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1315
#   Num Epochs = 5
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 2
#   Total optimization steps = 820
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='657' max='820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [657/820 2:34:57 < 38:33, 0.07 it/s, Epoch 4.00/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.285600</td>
#       <td>5.066072</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.631600</td>
#       <td>3.651306</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.055800</td>
#       <td>8.023211</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='39' max='110' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 39/110 01:09 < 02:10, 0.55 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 439
#   Batch size = 4
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-164
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-164/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-164/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 439
#   Batch size = 4
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-328
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-328/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-328/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 439
#   Batch size = 4
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-492
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-492/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-492/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 439
#   Batch size = 4
#     <div>
#
#       <progress value='820' max='820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [820/820 3:22:16, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.285600</td>
#       <td>5.066072</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.631600</td>
#       <td>3.651306</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.055800</td>
#       <td>8.023211</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.207500</td>
#       <td>8.693100</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.671000</td>
#       <td>8.782410</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-656
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-656/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-656/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 439
#   Batch size = 4
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-820
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-820/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-820/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-328 (score: 3.651305913925171).
# Using cuda_amp half precision backend
# Saving model checkpoint to /tmp/tmpu9sguz0z
# Configuration saved in /tmp/tmpu9sguz0z/config.json
# Model weights saved in /tmp/tmpu9sguz0z/pytorch_model.bin
# TrainOutput(global_step=820, training_loss=5.610103132666611, metrics={'train_runtime': 12026.6484, 'train_samples_per_second': 0.547, 'train_steps_per_second': 0.068, 'total_flos': 5.027265341472768e+16, 'train_loss': 5.610103132666611, 'epoch': 5.0})

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5114.658 MB of 5114.658 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>▃▁▇██</td></tr><tr><td>eval/runtime</td><td>█▇▂▁▁</td></tr><tr><td>eval/samples_per_second</td><td>▁▂▇██</td></tr><tr><td>eval/steps_per_second</td><td>▁▁███</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/learning_rate</td><td>▁▂▃▅▆████▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁</td></tr><tr><td>train/loss</td><td>▁▃▂▂▁▂▂▂▄▄▃▂▁▂▁▁▁▂▂▂▂▄▄▆▆▇▇▇▆█▇▇▇██▇██▆█</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>8.78241</td></tr><tr><td>eval/runtime</td><td>223.8346</td></tr><tr><td>eval/samples_per_second</td><td>1.961</td></tr><tr><td>eval/steps_per_second</td><td>0.491</td></tr><tr><td>train/epoch</td><td>5.0</td></tr><tr><td>train/global_step</td><td>820</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>8.671</td></tr><tr><td>train/total_flos</td><td>5.027265341472768e+16</td></tr><tr><td>train/train_loss</td><td>5.6101</td></tr><tr><td>train/train_runtime</td><td>12026.6484</td></tr><tr><td>train/train_samples_per_second</td><td>0.547</td></tr><tr><td>train/train_steps_per_second</td><td>0.068</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sunny-dust-9</strong>: <a href="https://wandb.ai/myashka/QA%20specific%20domain/runs/24n66wru" target="_blank">https://wandb.ai/myashka/QA%20specific%20domain/runs/24n66wru</a><br/>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220930_104058-24n66wru/logs</code>

# %% [markdown]
# # Evaluation

# %%
#!pip install bert_score, datasets, rouge_score, evaluate

# %%
import nltk
from datasets import load_metric
from evaluate import load

# %%
# model = AutoModelForCausalLM.from_pretrained(
#     "/content/drive/MyDrive/Colab Notebooks/vkr_data/results/checkpoint-328"
# ).to(device)

# %%
model = AutoModelForCausalLM.from_pretrained("./results/checkpoint-328").to(device)

# %%
model.config.use_cache = True

# %%
rouge = load_metric("rouge")
bertscore = load("bertscore")
# Out:
# Downloading builder script: 100%|█████████████████████████████████████████████████| 7.95k/7.95k [00:00<00:00, 7.67MB/s]

# %%
text_table = wandb.Table(
    columns=[
        "question",
        "generated_answer",
        "original_answer",
        "bert_precision",
        "bert_recall",
        "bert_f1",
        "rouge_score",
        "bleu_score",
        "len_of_generated_answer",
    ]
)

# %%
def evaluate_model(model, test_dataset, tokenizer, device, text_table, wandb_run):
    model.eval()

    bleu_scores = []
    rouge_scores = []
    bert_scores = []
    bert_precisions = []
    bert_recalls = []
    bert_f1s = []

    for encoded_ids, _, _, answer, question in tqdm(test_dataset):

        question_len = len(f"Question: {question}\nAnswer: ")

        text_to_answer = f"<|startoftext|>Question: {question}\nAnswer:"

        enc_text_to_answer = tokenizer(
            text_to_answer, return_tensors="pt"
        ).input_ids.to(device)

        generated_output = model.generate(
            enc_text_to_answer,
            do_sample=False,
            top_k=50,
            max_length=max_length,
            top_p=0.90,
            temperature=0,
            num_return_sequences=0,
            pad_token_id=tokenizer.eos_token_id,
        ).to("cpu")

        generated_q_a = tokenizer.decode(generated_output[0], skip_special_tokens=True)
        generated_a = generated_q_a[question_len:]

        bert_score = bertscore.compute(
            predictions=[generated_a], references=[answer], lang="en"
        )

        bleu_score = nltk.translate.bleu_score.sentence_bleu(answer, generated_a)
        rouge_score = rouge.compute(predictions=[generated_a], references=[answer])[
            "rouge1"
        ].mid.fmeasure

        text_table.add_data(
            question,
            generated_a,
            answer,
            bert_score["precision"],
            bert_score["recall"],
            bert_score["f1"],
            rouge_score,
            bleu_score,
            len(generated_a),
        )

    wandb_run.log({"evaluation_table": text_table})

    return (
        np.mean(bleu_scores),
        np.mean(rouge_scores),
        np.mean(bert_precisions),
        np.mean(bert_recalls),
        np.mean(bert_f1s),
    )

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
bleu_score, rouge_score, bert_precision, bert_recall, bert_f1 = evaluate_model(
    model, test_dataset, tokenizer, device, text_table, run
)
# Out:
#   0%|                                                                                          | 0/439 [00:00<?, ?it/s]
#
#
#
#
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 482/482 [00:00<00:00, 241kB/s]
#
#
#
#
#
# Downloading:   0%|                                                                          | 0.00/878k [00:00<?, ?B/s]
#
#
#
#
# Downloading:   4%|██▍                                                               | 32.0k/878k [00:00<00:02, 307kB/s]
#
#
#
#
# Downloading:   9%|██████                                                            | 80.0k/878k [00:00<00:02, 391kB/s]
#
#
#
#
# Downloading:  22%|██████████████▋                                                    | 192k/878k [00:00<00:01, 691kB/s]
#
#
#
#
# Downloading:  46%|██████████████████████████████                                    | 400k/878k [00:00<00:00, 1.19MB/s]
#
#
#
#
# Downloading: 100%|██████████████████████████████████████████████████████████████████| 878k/878k [00:00<00:00, 1.62MB/s]
#
#
#
#
#
# Downloading:   0%|                                                                          | 0.00/446k [00:00<?, ?B/s]
#
#
#
#
# Downloading:   9%|█████▉                                                            | 40.0k/446k [00:00<00:01, 392kB/s]
#
#
#
#
# Downloading:  21%|█████████████▋                                                    | 92.0k/446k [00:00<00:00, 453kB/s]
#
#
#
#
# Downloading:  46%|██████████████████████████████▋                                    | 204k/446k [00:00<00:00, 735kB/s]
#
#
#
#
# Downloading: 100%|██████████████████████████████████████████████████████████████████| 446k/446k [00:00<00:00, 1.06MB/s]
#
#
#
#
#
# Downloading:   0%|                                                                         | 0.00/1.33G [00:00<?, ?B/s]
#
#
#
#
# Downloading:   0%|▏                                                               | 2.74M/1.33G [00:00<00:49, 28.6MB/s]
#
#
#
#
# Downloading:   1%|▎                                                               | 7.54M/1.33G [00:00<00:34, 41.2MB/s]
#
#
#
#
# Downloading:   1%|▌                                                               | 12.2M/1.33G [00:00<00:31, 44.7MB/s]
#
#
#
#
# Downloading:   1%|▊                                                               | 16.8M/1.33G [00:00<00:30, 45.7MB/s]
#
#
#
#
# Downloading:   2%|█                                                               | 21.5M/1.33G [00:00<00:29, 47.0MB/s]
#
#
#
#
# Downloading:   2%|█▏                                                              | 26.4M/1.33G [00:00<00:28, 48.2MB/s]
#
#
#
#
# Downloading:   2%|█▍                                                              | 31.0M/1.33G [00:00<00:29, 47.5MB/s]
#
#
#
#
# Downloading:   3%|█▋                                                              | 35.7M/1.33G [00:00<00:28, 48.1MB/s]
#
#
#
#
# Downloading:   3%|█▉                                                              | 40.3M/1.33G [00:00<00:29, 47.5MB/s]
#
#
#
#
# Downloading:   3%|██                                                              | 44.9M/1.33G [00:01<00:28, 47.8MB/s]
#
#
#
#
# Downloading:   4%|██▎                                                             | 49.5M/1.33G [00:01<00:30, 44.7MB/s]
#
#
#
#
# Downloading:   4%|██▌                                                             | 53.8M/1.33G [00:01<00:31, 43.5MB/s]
#
#
#
#
# Downloading:   4%|██▋                                                             | 57.9M/1.33G [00:01<00:31, 42.8MB/s]
#
#
#
#
# Downloading:   5%|██▉                                                             | 62.1M/1.33G [00:01<00:31, 42.9MB/s]
#
#
#
#
# Downloading:   5%|███▏                                                            | 66.7M/1.33G [00:01<00:30, 44.3MB/s]
#
#
#
#
# Downloading:   5%|███▎                                                            | 71.2M/1.33G [00:01<00:29, 45.1MB/s]
#
#
#
#
# Downloading:   6%|███▌                                                            | 75.9M/1.33G [00:01<00:29, 46.4MB/s]
#
#
#
#
# Downloading:   6%|███▊                                                            | 80.8M/1.33G [00:01<00:28, 47.6MB/s]
#
#
#
#
# Downloading:   6%|████                                                            | 85.3M/1.33G [00:02<00:31, 42.1MB/s]
#
#
#
#
# Downloading:   7%|████▏                                                           | 89.4M/1.33G [00:02<00:33, 39.3MB/s]
#
#
#
#
# Downloading:   7%|████▍                                                           | 93.5M/1.33G [00:02<00:33, 40.0MB/s]
#
#
#
#
# Downloading:   7%|████▌                                                           | 97.6M/1.33G [00:02<00:32, 40.9MB/s]
#
#
#
#
# Downloading:   7%|████▊                                                            | 102M/1.33G [00:02<00:32, 41.1MB/s]
#
#
#
#
# Downloading:   8%|█████                                                            | 106M/1.33G [00:02<00:31, 41.5MB/s]
#
#
#
#
# Downloading:   8%|█████▎                                                           | 110M/1.33G [00:02<00:30, 42.6MB/s]
#
#
#
#
# Downloading:   8%|█████▍                                                           | 114M/1.33G [00:02<00:31, 42.1MB/s]
#
#
#
#
# Downloading:   9%|█████▋                                                           | 118M/1.33G [00:02<00:31, 41.9MB/s]
#
#
#
#
# Downloading:   9%|█████▊                                                           | 122M/1.33G [00:02<00:30, 42.0MB/s]
#
#
#
#
# Downloading:   9%|██████                                                           | 126M/1.33G [00:03<00:31, 41.2MB/s]
#
#
#
#
# Downloading:  10%|██████▏                                                          | 130M/1.33G [00:03<00:31, 41.2MB/s]
#
#
#
#
# Downloading:  10%|██████▍                                                          | 135M/1.33G [00:03<00:30, 42.4MB/s]
#
#
#
#
# Downloading:  10%|██████▋                                                          | 139M/1.33G [00:03<00:29, 43.6MB/s]
#
#
#
#
# Downloading:  11%|██████▊                                                          | 143M/1.33G [00:03<00:29, 43.8MB/s]
#
#
#
#
# Downloading:  11%|███████                                                          | 147M/1.33G [00:03<00:31, 40.1MB/s]
#
#
#
#
# Downloading:  11%|███████▏                                                         | 151M/1.33G [00:03<00:32, 39.4MB/s]
#
#
#
#
# Downloading:  11%|███████▍                                                         | 155M/1.33G [00:03<00:31, 40.4MB/s]
#
#
#
#
# Downloading:  12%|███████▌                                                         | 159M/1.33G [00:03<00:31, 40.0MB/s]
#
#
#
#
# Downloading:  12%|███████▊                                                         | 164M/1.33G [00:03<00:29, 42.5MB/s]
#
#
#
#
# Downloading:  12%|████████                                                         | 168M/1.33G [00:04<00:29, 42.9MB/s]
#
#
#
#
# Downloading:  13%|████████▏                                                        | 172M/1.33G [00:04<00:30, 40.2MB/s]
#
#
#
#
# Downloading:  13%|████████▍                                                        | 176M/1.33G [00:04<00:33, 37.0MB/s]
#
#
#
#
# Downloading:  13%|████████▌                                                        | 180M/1.33G [00:04<00:35, 34.7MB/s]
#
#
#
#
# Downloading:  13%|████████▊                                                        | 183M/1.33G [00:04<00:36, 34.0MB/s]
#
#
#
#
# Downloading:  14%|████████▉                                                        | 186M/1.33G [00:04<00:37, 33.1MB/s]
#
#
#
#
# Downloading:  14%|█████████                                                        | 190M/1.33G [00:04<00:38, 31.5MB/s]
#
#
#
#
# Downloading:  14%|█████████▏                                                       | 193M/1.33G [00:04<00:38, 32.1MB/s]
#
#
#
#
# Downloading:  14%|█████████▎                                                       | 196M/1.33G [00:05<00:38, 32.1MB/s]
#
#
#
#
# Downloading:  15%|█████████▌                                                       | 199M/1.33G [00:05<00:38, 31.9MB/s]
#
#
#
#
# Downloading:  15%|█████████▋                                                       | 203M/1.33G [00:05<00:36, 33.4MB/s]
#
#
#
#
# Downloading:  15%|█████████▊                                                       | 206M/1.33G [00:05<00:34, 34.8MB/s]
#
#
#
#
# Downloading:  15%|██████████                                                       | 210M/1.33G [00:05<00:32, 36.9MB/s]
#
#
#
#
# Downloading:  16%|██████████▎                                                      | 215M/1.33G [00:05<00:29, 40.1MB/s]
#
#
#
#
# Downloading:  16%|██████████▍                                                      | 220M/1.33G [00:05<00:27, 43.0MB/s]
#
#
#
#
# Downloading:  17%|██████████▋                                                      | 225M/1.33G [00:05<00:25, 46.4MB/s]
#
#
#
#
# Downloading:  17%|██████████▉                                                      | 229M/1.33G [00:05<00:25, 46.2MB/s]
#
#
#
#
# Downloading:  17%|███████████▏                                                     | 234M/1.33G [00:05<00:24, 47.4MB/s]
#
#
#
#
# Downloading:  18%|███████████▍                                                     | 239M/1.33G [00:06<00:25, 46.6MB/s]
#
#
#
#
# Downloading:  18%|███████████▌                                                     | 243M/1.33G [00:06<00:25, 46.1MB/s]
#
#
#
#
# Downloading:  18%|███████████▊                                                     | 247M/1.33G [00:06<00:25, 45.6MB/s]
#
#
#
#
# Downloading:  19%|████████████                                                     | 252M/1.33G [00:06<00:27, 42.8MB/s]
#
#
#
#
# Downloading:  19%|████████████▏                                                    | 256M/1.33G [00:06<00:26, 43.5MB/s]
#
#
#
#
# Downloading:  19%|████████████▍                                                    | 261M/1.33G [00:06<00:26, 44.3MB/s]
#
#
#
#
# Downloading:  20%|████████████▋                                                    | 266M/1.33G [00:06<00:24, 46.5MB/s]
#
#
#
#
# Downloading:  20%|████████████▉                                                    | 271M/1.33G [00:06<00:23, 48.7MB/s]
#
#
#
#
# Downloading:  20%|█████████████▏                                                   | 275M/1.33G [00:06<00:24, 47.3MB/s]
#
#
#
#
# Downloading:  21%|█████████████▍                                                   | 280M/1.33G [00:07<00:25, 44.3MB/s]
#
#
#
#
# Downloading:  21%|█████████████▌                                                   | 284M/1.33G [00:07<00:25, 44.3MB/s]
#
#
#
#
# Downloading:  21%|█████████████▊                                                   | 289M/1.33G [00:07<00:24, 45.5MB/s]
#
#
#
#
# Downloading:  22%|██████████████                                                   | 293M/1.33G [00:07<00:24, 45.9MB/s]
#
#
#
#
# Downloading:  22%|██████████████▏                                                  | 298M/1.33G [00:07<00:24, 46.2MB/s]
#
#
#
#
# Downloading:  22%|██████████████▍                                                  | 302M/1.33G [00:07<00:25, 43.5MB/s]
#
#
#
#
# Downloading:  23%|██████████████▋                                                  | 306M/1.33G [00:07<00:26, 41.1MB/s]
#
#
#
#
# Downloading:  23%|██████████████▊                                                  | 310M/1.33G [00:07<00:26, 41.0MB/s]
#
#
#
#
# Downloading:  23%|███████████████                                                  | 315M/1.33G [00:07<00:25, 42.2MB/s]
#
#
#
#
# Downloading:  23%|███████████████▏                                                 | 319M/1.33G [00:07<00:26, 40.5MB/s]
#
#
#
#
# Downloading:  24%|███████████████▍                                                 | 323M/1.33G [00:08<00:27, 39.9MB/s]
#
#
#
#
# Downloading:  24%|███████████████▌                                                 | 327M/1.33G [00:08<00:28, 38.1MB/s]
#
#
#
#
# Downloading:  24%|███████████████▊                                                 | 330M/1.33G [00:08<00:29, 36.2MB/s]
#
#
#
#
# Downloading:  25%|███████████████▉                                                 | 334M/1.33G [00:08<00:32, 33.3MB/s]
#
#
#
#
# Downloading:  25%|████████████████                                                 | 337M/1.33G [00:08<00:35, 30.2MB/s]
#
#
#
#
# Downloading:  25%|████████████████▏                                                | 340M/1.33G [00:08<00:36, 29.0MB/s]
#
#
#
#
# Downloading:  25%|████████████████▍                                                | 343M/1.33G [00:08<00:40, 26.4MB/s]
#
#
#
#
# Downloading:  25%|████████████████▌                                                | 345M/1.33G [00:08<00:42, 24.8MB/s]
#
#
#
#
# Downloading:  26%|████████████████▌                                                | 348M/1.33G [00:09<00:43, 24.6MB/s]
#
#
#
#
# Downloading:  26%|████████████████▋                                                | 350M/1.33G [00:09<00:40, 25.8MB/s]
#
#
#
#
# Downloading:  26%|████████████████▉                                                | 353M/1.33G [00:09<00:38, 27.5MB/s]
#
#
#
#
# Downloading:  26%|█████████████████                                                | 356M/1.33G [00:09<00:38, 27.2MB/s]
#
#
#
#
# Downloading:  26%|█████████████████▏                                               | 359M/1.33G [00:09<00:35, 29.4MB/s]
#
#
#
#
# Downloading:  27%|█████████████████▎                                               | 362M/1.33G [00:09<00:35, 29.4MB/s]
#
#
#
#
# Downloading:  27%|█████████████████▍                                               | 365M/1.33G [00:09<00:36, 28.7MB/s]
#
#
#
#
# Downloading:  27%|█████████████████▌                                               | 369M/1.33G [00:09<00:33, 30.8MB/s]
#
#
#
#
# Downloading:  27%|█████████████████▊                                               | 372M/1.33G [00:09<00:32, 31.5MB/s]
#
#
#
#
# Downloading:  28%|█████████████████▉                                               | 375M/1.33G [00:09<00:32, 31.5MB/s]
#
#
#
#
# Downloading:  28%|██████████████████                                               | 378M/1.33G [00:10<00:54, 18.9MB/s]
#
#
#
#
# Downloading:  28%|██████████████████▏                                              | 381M/1.33G [00:10<00:48, 21.2MB/s]
#
#
#
#
# Downloading:  28%|██████████████████▎                                              | 383M/1.33G [00:10<00:45, 22.4MB/s]
#
#
#
#
# Downloading:  28%|██████████████████▍                                              | 387M/1.33G [00:10<00:38, 26.3MB/s]
#
#
#
#
# Downloading:  29%|██████████████████▋                                              | 390M/1.33G [00:10<00:37, 27.0MB/s]
#
#
#
#
# Downloading:  29%|██████████████████▊                                              | 393M/1.33G [00:10<00:37, 26.9MB/s]
#
#
#
#
# Downloading:  29%|██████████████████▉                                              | 395M/1.33G [00:10<00:39, 25.9MB/s]
#
#
#
#
# Downloading:  29%|███████████████████                                              | 398M/1.33G [00:11<00:40, 24.6MB/s]
#
#
#
#
# Downloading:  29%|███████████████████▏                                             | 401M/1.33G [00:11<00:42, 23.9MB/s]
# Downloading:  30%|███████████████████▎                                             | 403M/1.33G [00:11<00:41, 24.1MB/s]
#
#
#
#
# Downloading:  30%|███████████████████▍                                             | 405M/1.33G [00:11<00:40, 24.9MB/s]
#
#
#
#
# Downloading:  30%|███████████████████▌                                             | 408M/1.33G [00:11<00:38, 26.2MB/s]
#
#
#
#
# Downloading:  30%|███████████████████▋                                             | 411M/1.33G [00:11<00:37, 26.5MB/s]
#
#
#
#
# Downloading:  30%|███████████████████▊                                             | 413M/1.33G [00:11<00:39, 25.0MB/s]
#
#
#
#
# Downloading:  31%|███████████████████▉                                             | 416M/1.33G [00:11<00:36, 26.8MB/s]
#
#
#
#
# Downloading:  31%|████████████████████                                             | 420M/1.33G [00:11<00:33, 29.2MB/s]
#
#
#
#
# Downloading:  31%|████████████████████▏                                            | 423M/1.33G [00:12<00:31, 30.9MB/s]
#
#
#
#
# Downloading:  31%|████████████████████▍                                            | 427M/1.33G [00:12<00:29, 32.8MB/s]
#
#
#
#
# Downloading:  32%|████████████████████▌                                            | 430M/1.33G [00:12<00:28, 34.4MB/s]
#
#
#
#
# Downloading:  32%|████████████████████▊                                            | 434M/1.33G [00:12<00:26, 36.0MB/s]
#
#
#
#
# Downloading:  32%|████████████████████▉                                            | 438M/1.33G [00:12<00:26, 36.2MB/s]
#
#
#
#
# Downloading:  32%|█████████████████████                                            | 442M/1.33G [00:12<00:25, 37.4MB/s]
#
#
#
#
# Downloading:  33%|█████████████████████▎                                           | 446M/1.33G [00:12<00:24, 38.5MB/s]
#
#
#
#
# Downloading:  33%|█████████████████████▍                                           | 449M/1.33G [00:12<00:24, 39.1MB/s]
#
#
#
#
# Downloading:  33%|█████████████████████▋                                           | 453M/1.33G [00:12<00:26, 35.3MB/s]
#
#
#
#
# Downloading:  34%|█████████████████████▊                                           | 457M/1.33G [00:13<00:29, 31.7MB/s]
#
#
#
#
# Downloading:  34%|█████████████████████▉                                           | 460M/1.33G [00:13<00:29, 31.7MB/s]
#
#
#
#
# Downloading:  34%|██████████████████████                                           | 463M/1.33G [00:13<00:31, 29.5MB/s]
#
#
#
#
# Downloading:  34%|██████████████████████▎                                          | 466M/1.33G [00:13<00:31, 29.6MB/s]
#
#
#
#
# Downloading:  34%|██████████████████████▍                                          | 469M/1.33G [00:13<00:30, 30.8MB/s]
#
#
#
#
# Downloading:  35%|██████████████████████▌                                          | 473M/1.33G [00:13<00:28, 33.1MB/s]
#
#
#
#
# Downloading:  35%|██████████████████████▊                                          | 477M/1.33G [00:13<00:25, 35.7MB/s]
#
#
#
#
# Downloading:  35%|███████████████████████                                          | 481M/1.33G [00:13<00:23, 39.2MB/s]
#
#
#
#
# Downloading:  36%|███████████████████████▏                                         | 486M/1.33G [00:13<00:22, 41.4MB/s]
#
#
#
#
# Downloading:  36%|███████████████████████▍                                         | 490M/1.33G [00:13<00:22, 40.6MB/s]
#
#
#
#
# Downloading:  36%|███████████████████████▋                                         | 496M/1.33G [00:14<00:19, 45.9MB/s]
#
#
#
#
# Downloading:  37%|███████████████████████▉                                         | 501M/1.33G [00:14<00:20, 44.4MB/s]
#
#
#
#
# Downloading:  37%|████████████████████████▏                                        | 505M/1.33G [00:14<00:20, 44.0MB/s]
#
#
#
#
# Downloading:  37%|████████████████████████▎                                        | 509M/1.33G [00:14<00:21, 42.2MB/s]
#
#
#
#
# Downloading:  38%|████████████████████████▌                                        | 513M/1.33G [00:14<00:21, 40.6MB/s]
#
#
#
#
# Downloading:  38%|████████████████████████▋                                        | 517M/1.33G [00:14<00:22, 39.3MB/s]
#
#
#
#
# Downloading:  38%|████████████████████████▉                                        | 521M/1.33G [00:14<00:22, 39.7MB/s]
#
#
#
#
# Downloading:  39%|█████████████████████████                                        | 525M/1.33G [00:14<00:21, 40.2MB/s]
#
#
#
#
# Downloading:  39%|█████████████████████████▎                                       | 529M/1.33G [00:14<00:20, 42.5MB/s]
#
#
#
#
# Downloading:  39%|█████████████████████████▌                                       | 534M/1.33G [00:15<00:19, 43.9MB/s]
#
#
#
#
# Downloading:  40%|█████████████████████████▋                                       | 539M/1.33G [00:15<00:18, 45.4MB/s]
#
#
#
#
# Downloading:  40%|█████████████████████████▉                                       | 543M/1.33G [00:15<00:19, 44.5MB/s]
#
#
#
#
# Downloading:  40%|██████████████████████████▏                                      | 548M/1.33G [00:15<00:18, 45.6MB/s]
#
#
#
#
# Downloading:  41%|██████████████████████████▍                                      | 553M/1.33G [00:15<00:17, 48.2MB/s]
#
#
#
#
# Downloading:  41%|██████████████████████████▋                                      | 557M/1.33G [00:15<00:17, 47.9MB/s]
#
#
#
#
# Downloading:  41%|██████████████████████████▊                                      | 562M/1.33G [00:15<00:17, 47.1MB/s]
#
#
#
#
# Downloading:  42%|███████████████████████████                                      | 567M/1.33G [00:15<00:17, 46.9MB/s]
#
#
#
#
# Downloading:  42%|███████████████████████████▎                                     | 571M/1.33G [00:15<00:17, 47.7MB/s]
#
#
#
#
# Downloading:  42%|███████████████████████████▌                                     | 576M/1.33G [00:15<00:17, 46.0MB/s]
#
#
#
#
# Downloading:  43%|███████████████████████████▋                                     | 580M/1.33G [00:16<00:18, 44.1MB/s]
#
#
#
#
# Downloading:  43%|███████████████████████████▉                                     | 584M/1.33G [00:16<00:18, 44.1MB/s]
#
#
#
#
# Downloading:  43%|████████████████████████████▏                                    | 589M/1.33G [00:16<00:18, 43.3MB/s]
#
#
#
#
# Downloading:  44%|████████████████████████████▎                                    | 593M/1.33G [00:16<00:18, 44.2MB/s]
#
#
#
#
# Downloading:  44%|████████████████████████████▌                                    | 597M/1.33G [00:16<00:18, 42.6MB/s]
#
#
#
#
# Downloading:  44%|████████████████████████████▋                                    | 601M/1.33G [00:16<00:19, 41.2MB/s]
#
#
#
#
# Downloading:  45%|████████████████████████████▉                                    | 605M/1.33G [00:16<00:20, 39.4MB/s]
#
#
#
#
# Downloading:  45%|█████████████████████████████                                    | 609M/1.33G [00:16<00:21, 37.2MB/s]
#
#
#
#
# Downloading:  45%|█████████████████████████████▎                                   | 613M/1.33G [00:16<00:22, 34.6MB/s]
#
#
#
#
# Downloading:  45%|█████████████████████████████▍                                   | 616M/1.33G [00:17<00:23, 33.1MB/s]
#
#
#
#
# Downloading:  46%|█████████████████████████████▌                                   | 619M/1.33G [00:17<00:24, 31.5MB/s]
#
#
#
#
# Downloading:  46%|█████████████████████████████▋                                   | 622M/1.33G [00:17<00:24, 31.0MB/s]
#
#
#
#
# Downloading:  46%|█████████████████████████████▉                                   | 625M/1.33G [00:17<00:25, 30.2MB/s]
#
#
#
#
# Downloading:  46%|██████████████████████████████                                   | 628M/1.33G [00:17<00:28, 27.2MB/s]
#
#
#
#
# Downloading:  46%|██████████████████████████████▏                                  | 631M/1.33G [00:17<00:30, 25.2MB/s]
#
#
#
#
# Downloading:  47%|██████████████████████████████▎                                  | 633M/1.33G [00:17<00:31, 24.3MB/s]
#
#
#
#
# Downloading:  47%|██████████████████████████████▍                                  | 636M/1.33G [00:17<00:30, 24.6MB/s]
#
#
#
#
# Downloading:  47%|██████████████████████████████▍                                  | 638M/1.33G [00:18<00:34, 21.6MB/s]
#
#
#
#
# Downloading:  47%|██████████████████████████████▌                                  | 640M/1.33G [00:18<00:37, 19.9MB/s]
#
#
#
#
# Downloading:  47%|██████████████████████████████▋                                  | 643M/1.33G [00:18<00:34, 21.9MB/s]
#
#
#
#
# Downloading:  48%|██████████████████████████████▉                                  | 646M/1.33G [00:18<00:29, 25.4MB/s]
#
#
#
#
# Downloading:  48%|███████████████████████████████                                  | 650M/1.33G [00:18<00:24, 30.6MB/s]
#
#
#
#
# Downloading:  48%|███████████████████████████████▎                                 | 655M/1.33G [00:18<00:21, 34.8MB/s]
#
#
#
#
# Downloading:  49%|███████████████████████████████▌                                 | 660M/1.33G [00:18<00:18, 39.3MB/s]
#
#
#
#
# Downloading:  49%|███████████████████████████████▋                                 | 664M/1.33G [00:18<00:17, 40.7MB/s]
#
#
#
#
# Downloading:  49%|███████████████████████████████▉                                 | 669M/1.33G [00:18<00:16, 43.9MB/s]
#
#
#
#
# Downloading:  49%|████████████████████████████████▏                                | 673M/1.33G [00:19<00:16, 42.7MB/s]
#
#
#
#
# Downloading:  50%|████████████████████████████████▍                                | 678M/1.33G [00:19<00:16, 44.2MB/s]
#
#
#
#
# Downloading:  50%|████████████████████████████████▌                                | 682M/1.33G [00:19<00:17, 40.4MB/s]
#
#
#
#
# Downloading:  50%|████████████████████████████████▊                                | 686M/1.33G [00:19<00:18, 38.0MB/s]
#
#
#
#
# Downloading:  51%|████████████████████████████████▉                                | 690M/1.33G [00:19<00:19, 36.0MB/s]
#
#
#
#
# Downloading:  51%|█████████████████████████████████▏                               | 693M/1.33G [00:19<00:20, 34.6MB/s]
#
#
#
#
# Downloading:  51%|█████████████████████████████████▎                               | 696M/1.33G [00:19<00:20, 33.6MB/s]
#
#
#
#
# Downloading:  52%|█████████████████████████████████▍                               | 701M/1.33G [00:19<00:18, 36.4MB/s]
#
#
#
#
# Downloading:  52%|█████████████████████████████████▋                               | 704M/1.33G [00:19<00:18, 36.7MB/s]
#
#
#
#
# Downloading:  52%|█████████████████████████████████▊                               | 708M/1.33G [00:20<00:18, 36.0MB/s]
#
#
#
#
# Downloading:  52%|█████████████████████████████████▉                               | 711M/1.33G [00:20<00:20, 33.2MB/s]
#
#
#
#
# Downloading:  53%|██████████████████████████████████▏                              | 714M/1.33G [00:20<00:35, 18.8MB/s]
#
#
#
#
# Downloading:  53%|██████████████████████████████████▎                              | 717M/1.33G [00:20<00:31, 21.1MB/s]
#
#
#
#
# Downloading:  53%|██████████████████████████████████▍                              | 721M/1.33G [00:20<00:27, 24.2MB/s]
#
#
#
#
# Downloading:  53%|██████████████████████████████████▋                              | 724M/1.33G [00:20<00:24, 27.0MB/s]
#
#
#
#
# Downloading:  54%|██████████████████████████████████▊                              | 728M/1.33G [00:20<00:21, 30.5MB/s]
#
#
#
#
# Downloading:  54%|███████████████████████████████████                              | 733M/1.33G [00:21<00:19, 34.3MB/s]
#
#
#
#
# Downloading:  54%|███████████████████████████████████▏                             | 736M/1.33G [00:21<00:18, 35.3MB/s]
#
#
#
#
# Downloading:  54%|███████████████████████████████████▎                             | 740M/1.33G [00:21<00:18, 35.3MB/s]
#
#
#
#
# Downloading:  55%|███████████████████████████████████▌                             | 744M/1.33G [00:21<00:18, 34.2MB/s]
#
#
#
#
# Downloading:  55%|███████████████████████████████████▋                             | 747M/1.33G [00:21<00:19, 33.6MB/s]
#
#
#
#
# Downloading:  55%|███████████████████████████████████▊                             | 750M/1.33G [00:21<00:18, 34.1MB/s]
#
#
#
#
# Downloading:  55%|████████████████████████████████████                             | 754M/1.33G [00:21<00:19, 32.9MB/s]
#
#
#
#
# Downloading:  56%|████████████████████████████████████▏                            | 757M/1.33G [00:21<00:19, 31.8MB/s]
#
#
#
#
# Downloading:  56%|████████████████████████████████████▎                            | 760M/1.33G [00:21<00:19, 32.0MB/s]
#
#
#
#
# Downloading:  56%|████████████████████████████████████▍                            | 764M/1.33G [00:22<00:18, 33.6MB/s]
#
#
#
#
# Downloading:  56%|████████████████████████████████████▋                            | 767M/1.33G [00:22<00:17, 34.7MB/s]
#
#
#
#
# Downloading:  57%|████████████████████████████████████▊                            | 771M/1.33G [00:22<00:17, 35.0MB/s]
#
#
#
#
# Downloading:  57%|████████████████████████████████████▉                            | 774M/1.33G [00:22<00:17, 35.1MB/s]
#
#
#
#
# Downloading:  57%|█████████████████████████████████████▏                           | 777M/1.33G [00:22<00:17, 34.7MB/s]
#
#
#
#
# Downloading:  57%|█████████████████████████████████████▎                           | 781M/1.33G [00:22<00:16, 35.9MB/s]
#
#
#
#
# Downloading:  58%|█████████████████████████████████████▌                           | 785M/1.33G [00:22<00:16, 37.3MB/s]
#
#
#
#
# Downloading:  58%|█████████████████████████████████████▋                           | 788M/1.33G [00:22<00:16, 37.0MB/s]
#
#
#
#
# Downloading:  58%|█████████████████████████████████████▊                           | 792M/1.33G [00:22<00:15, 37.8MB/s]
#
#
#
#
# Downloading:  59%|██████████████████████████████████████                           | 796M/1.33G [00:22<00:15, 39.0MB/s]
#
#
#
#
# Downloading:  59%|██████████████████████████████████████▏                          | 800M/1.33G [00:23<00:14, 39.6MB/s]
#
#
#
#
# Downloading:  59%|██████████████████████████████████████▍                          | 804M/1.33G [00:23<00:14, 39.0MB/s]
#
#
#
#
# Downloading:  59%|██████████████████████████████████████▌                          | 808M/1.33G [00:23<00:15, 37.4MB/s]
#
#
#
#
# Downloading:  60%|██████████████████████████████████████▊                          | 812M/1.33G [00:23<00:14, 38.7MB/s]
#
#
#
#
# Downloading:  60%|██████████████████████████████████████▉                          | 816M/1.33G [00:23<00:14, 40.0MB/s]
#
#
#
#
# Downloading:  60%|███████████████████████████████████████▏                         | 820M/1.33G [00:23<00:13, 42.3MB/s]
#
#
#
#
# Downloading:  61%|███████████████████████████████████████▍                         | 825M/1.33G [00:23<00:12, 43.5MB/s]
#
#
#
#
# Downloading:  61%|███████████████████████████████████████▋                         | 830M/1.33G [00:23<00:12, 45.8MB/s]
#
#
#
#
# Downloading:  61%|███████████████████████████████████████▉                         | 835M/1.33G [00:23<00:11, 46.8MB/s]
#
#
#
#
# Downloading:  62%|████████████████████████████████████████                         | 839M/1.33G [00:23<00:11, 46.8MB/s]
# Downloading:  62%|████████████████████████████████████████▎                        | 844M/1.33G [00:24<00:11, 46.9MB/s]
#
#
#
#
# Downloading:  62%|████████████████████████████████████████▌                        | 848M/1.33G [00:24<00:12, 43.6MB/s]
#
#
#
#
# Downloading:  63%|████████████████████████████████████████▊                        | 853M/1.33G [00:24<00:11, 46.9MB/s]
#
#
#
#
# Downloading:  63%|█████████████████████████████████████████                        | 858M/1.33G [00:24<00:11, 46.2MB/s]
#
#
#
#
# Downloading:  63%|█████████████████████████████████████████▏                       | 862M/1.33G [00:24<00:11, 46.1MB/s]
#
#
#
#
# Downloading:  64%|█████████████████████████████████████████▍                       | 867M/1.33G [00:24<00:11, 45.1MB/s]
#
#
#
#
# Downloading:  64%|█████████████████████████████████████████▋                       | 871M/1.33G [00:24<00:11, 43.5MB/s]
#
#
#
#
# Downloading:  64%|█████████████████████████████████████████▊                       | 875M/1.33G [00:24<00:12, 42.1MB/s]
#
#
#
#
# Downloading:  65%|██████████████████████████████████████████                       | 879M/1.33G [00:24<00:12, 40.7MB/s]
#
#
#
#
# Downloading:  65%|██████████████████████████████████████████▏                      | 883M/1.33G [00:25<00:12, 39.9MB/s]
#
#
#
#
# Downloading:  65%|██████████████████████████████████████████▍                      | 887M/1.33G [00:25<00:12, 40.0MB/s]
#
#
#
#
# Downloading:  66%|██████████████████████████████████████████▌                      | 891M/1.33G [00:25<00:12, 40.4MB/s]
#
#
#
#
# Downloading:  66%|██████████████████████████████████████████▊                      | 895M/1.33G [00:25<00:12, 40.0MB/s]
#
#
#
#
# Downloading:  66%|██████████████████████████████████████████▉                      | 899M/1.33G [00:25<00:12, 39.4MB/s]
#
#
#
#
# Downloading:  66%|███████████████████████████████████████████▏                     | 902M/1.33G [00:25<00:12, 38.4MB/s]
#
#
#
#
# Downloading:  67%|███████████████████████████████████████████▎                     | 906M/1.33G [00:25<00:13, 36.4MB/s]
#
#
#
#
# Downloading:  67%|███████████████████████████████████████████▍                     | 910M/1.33G [00:25<00:12, 36.4MB/s]
#
#
#
#
# Downloading:  67%|███████████████████████████████████████████▋                     | 913M/1.33G [00:25<00:13, 35.7MB/s]
#
#
#
#
# Downloading:  67%|███████████████████████████████████████████▊                     | 917M/1.33G [00:26<00:14, 32.5MB/s]
#
#
#
#
# Downloading:  68%|███████████████████████████████████████████▉                     | 920M/1.33G [00:26<00:14, 32.6MB/s]
#
#
#
#
# Downloading:  68%|████████████████████████████████████████████                     | 923M/1.33G [00:26<00:13, 33.1MB/s]
#
#
#
#
# Downloading:  68%|████████████████████████████████████████████▎                    | 926M/1.33G [00:26<00:14, 31.5MB/s]
#
#
#
#
# Downloading:  68%|████████████████████████████████████████████▍                    | 929M/1.33G [00:26<00:14, 31.5MB/s]
#
#
#
#
# Downloading:  69%|████████████████████████████████████████████▌                    | 932M/1.33G [00:26<00:14, 30.9MB/s]
#
#
#
#
# Downloading:  69%|████████████████████████████████████████████▊                    | 937M/1.33G [00:26<00:12, 36.5MB/s]
#
#
#
#
# Downloading:  69%|████████████████████████████████████████████▉                    | 941M/1.33G [00:26<00:11, 38.3MB/s]
#
#
#
#
# Downloading:  70%|█████████████████████████████████████████████▏                   | 946M/1.33G [00:26<00:10, 40.7MB/s]
#
#
#
#
# Downloading:  70%|█████████████████████████████████████████████▍                   | 950M/1.33G [00:26<00:10, 41.0MB/s]
#
#
#
#
# Downloading:  70%|█████████████████████████████████████████████▌                   | 954M/1.33G [00:27<00:10, 41.1MB/s]
#
#
#
#
# Downloading:  71%|█████████████████████████████████████████████▊                   | 959M/1.33G [00:27<00:09, 44.0MB/s]
#
#
#
#
# Downloading:  71%|██████████████████████████████████████████████                   | 964M/1.33G [00:27<00:09, 45.9MB/s]
#
#
#
#
# Downloading:  71%|██████████████████████████████████████████████▎                  | 968M/1.33G [00:27<00:09, 44.2MB/s]
#
#
#
#
# Downloading:  72%|██████████████████████████████████████████████▌                  | 973M/1.33G [00:27<00:08, 48.1MB/s]
#
#
#
#
# Downloading:  72%|██████████████████████████████████████████████▊                  | 978M/1.33G [00:27<00:08, 46.6MB/s]
#
#
#
#
# Downloading:  72%|██████████████████████████████████████████████▉                  | 983M/1.33G [00:27<00:08, 46.0MB/s]
#
#
#
#
# Downloading:  73%|███████████████████████████████████████████████▏                 | 987M/1.33G [00:27<00:08, 44.5MB/s]
#
#
#
#
# Downloading:  73%|███████████████████████████████████████████████▍                 | 991M/1.33G [00:27<00:08, 43.3MB/s]
#
#
#
#
# Downloading:  73%|███████████████████████████████████████████████▌                 | 995M/1.33G [00:28<00:09, 41.3MB/s]
#
#
#
#
# Downloading:  74%|███████████████████████████████████████████████                 | 0.98G/1.33G [00:28<00:09, 42.0MB/s]
#
#
#
#
# Downloading:  74%|███████████████████████████████████████████████▏                | 0.98G/1.33G [00:28<00:09, 40.8MB/s]
#
#
#
#
# Downloading:  74%|███████████████████████████████████████████████▍                | 0.98G/1.33G [00:28<00:08, 41.7MB/s]
#
#
#
#
# Downloading:  75%|███████████████████████████████████████████████▋                | 0.99G/1.33G [00:28<00:07, 46.2MB/s]
#
#
#
#
# Downloading:  75%|███████████████████████████████████████████████▉                | 0.99G/1.33G [00:28<00:07, 48.1MB/s]
#
#
#
#
# Downloading:  75%|████████████████████████████████████████████████▏               | 1.00G/1.33G [00:28<00:07, 44.9MB/s]
#
#
#
#
# Downloading:  76%|████████████████████████████████████████████████▍               | 1.01G/1.33G [00:28<00:07, 48.0MB/s]
#
#
#
#
# Downloading:  76%|████████████████████████████████████████████████▋               | 1.01G/1.33G [00:28<00:06, 51.2MB/s]
#
#
#
#
# Downloading:  77%|█████████████████████████████████████████████████               | 1.02G/1.33G [00:29<00:06, 54.9MB/s]
#
#
#
#
# Downloading:  77%|█████████████████████████████████████████████████▎              | 1.02G/1.33G [00:29<00:06, 52.1MB/s]
#
#
#
#
# Downloading:  77%|█████████████████████████████████████████████████▍              | 1.03G/1.33G [00:29<00:06, 52.5MB/s]
#
#
#
#
# Downloading:  78%|█████████████████████████████████████████████████▋              | 1.03G/1.33G [00:29<00:06, 52.5MB/s]
#
#
#
#
# Downloading:  78%|█████████████████████████████████████████████████▉              | 1.04G/1.33G [00:29<00:05, 52.8MB/s]
#
#
#
#
# Downloading:  78%|██████████████████████████████████████████████████▏             | 1.04G/1.33G [00:29<00:05, 54.3MB/s]
#
#
#
#
# Downloading:  79%|██████████████████████████████████████████████████▍             | 1.05G/1.33G [00:29<00:05, 52.6MB/s]
#
#
#
#
# Downloading:  79%|██████████████████████████████████████████████████▋             | 1.05G/1.33G [00:29<00:06, 48.9MB/s]
#
#
#
#
# Downloading:  80%|███████████████████████████████████████████████████             | 1.06G/1.33G [00:29<00:05, 52.9MB/s]
#
#
#
#
# Downloading:  80%|███████████████████████████████████████████████████▏            | 1.06G/1.33G [00:29<00:05, 53.0MB/s]
#
#
#
#
# Downloading:  80%|███████████████████████████████████████████████████▍            | 1.07G/1.33G [00:30<00:05, 52.9MB/s]
#
#
#
#
# Downloading:  81%|███████████████████████████████████████████████████▋            | 1.07G/1.33G [00:30<00:05, 51.0MB/s]
#
#
#
#
# Downloading:  81%|███████████████████████████████████████████████████▉            | 1.08G/1.33G [00:30<00:05, 48.2MB/s]
#
#
#
#
# Downloading:  82%|████████████████████████████████████████████████████▏           | 1.08G/1.33G [00:30<00:05, 46.9MB/s]
#
#
#
#
# Downloading:  82%|████████████████████████████████████████████████████▍           | 1.09G/1.33G [00:30<00:05, 43.2MB/s]
#
#
#
#
# Downloading:  82%|████████████████████████████████████████████████████▌           | 1.09G/1.33G [00:30<00:06, 42.2MB/s]
#
#
#
#
# Downloading:  82%|████████████████████████████████████████████████████▊           | 1.10G/1.33G [00:30<00:05, 42.8MB/s]
#
#
#
#
# Downloading:  83%|████████████████████████████████████████████████████▉           | 1.10G/1.33G [00:30<00:06, 39.2MB/s]
#
#
#
#
# Downloading:  83%|█████████████████████████████████████████████████████▏          | 1.10G/1.33G [00:30<00:05, 42.6MB/s]
#
#
#
#
# Downloading:  83%|█████████████████████████████████████████████████████▍          | 1.11G/1.33G [00:31<00:05, 43.5MB/s]
#
#
#
#
# Downloading:  84%|█████████████████████████████████████████████████████▌          | 1.11G/1.33G [00:31<00:05, 43.5MB/s]
#
#
#
#
# Downloading:  84%|█████████████████████████████████████████████████████▊          | 1.12G/1.33G [00:31<00:04, 45.6MB/s]
#
#
#
#
# Downloading:  84%|██████████████████████████████████████████████████████          | 1.12G/1.33G [00:31<00:04, 46.4MB/s]
#
#
#
#
# Downloading:  85%|██████████████████████████████████████████████████████▎         | 1.13G/1.33G [00:31<00:04, 48.1MB/s]
#
#
#
#
# Downloading:  85%|██████████████████████████████████████████████████████▌         | 1.13G/1.33G [00:31<00:04, 50.0MB/s]
#
#
#
#
# Downloading:  86%|██████████████████████████████████████████████████████▊         | 1.14G/1.33G [00:31<00:04, 50.0MB/s]
#
#
#
#
# Downloading:  86%|███████████████████████████████████████████████████████         | 1.14G/1.33G [00:31<00:03, 51.9MB/s]
#
#
#
#
# Downloading:  86%|███████████████████████████████████████████████████████▎        | 1.15G/1.33G [00:31<00:03, 48.7MB/s]
#
#
#
#
# Downloading:  87%|███████████████████████████████████████████████████████▍        | 1.15G/1.33G [00:32<00:03, 48.1MB/s]
#
#
#
#
# Downloading:  87%|███████████████████████████████████████████████████████▋        | 1.16G/1.33G [00:32<00:03, 46.8MB/s]
#
#
#
#
# Downloading:  87%|███████████████████████████████████████████████████████▉        | 1.16G/1.33G [00:32<00:03, 46.4MB/s]
#
#
#
#
# Downloading:  88%|████████████████████████████████████████████████████████        | 1.16G/1.33G [00:32<00:03, 45.6MB/s]
#
#
#
#
# Downloading:  88%|████████████████████████████████████████████████████████▎       | 1.17G/1.33G [00:32<00:03, 44.0MB/s]
#
#
#
#
# Downloading:  88%|████████████████████████████████████████████████████████▌       | 1.17G/1.33G [00:32<00:03, 45.1MB/s]
#
#
#
#
# Downloading:  89%|████████████████████████████████████████████████████████▋       | 1.18G/1.33G [00:32<00:03, 45.2MB/s]
#
#
#
#
# Downloading:  89%|████████████████████████████████████████████████████████▉       | 1.18G/1.33G [00:32<00:03, 43.7MB/s]
#
#
#
#
# Downloading:  89%|█████████████████████████████████████████████████████████▏      | 1.19G/1.33G [00:32<00:03, 43.8MB/s]
#
#
#
#
# Downloading:  90%|█████████████████████████████████████████████████████████▎      | 1.19G/1.33G [00:32<00:03, 43.4MB/s]
#
#
#
#
# Downloading:  90%|█████████████████████████████████████████████████████████▌      | 1.19G/1.33G [00:33<00:03, 43.7MB/s]
#
#
#
#
# Downloading:  90%|█████████████████████████████████████████████████████████▊      | 1.20G/1.33G [00:33<00:03, 44.7MB/s]
#
#
#
#
# Downloading:  91%|█████████████████████████████████████████████████████████▉      | 1.20G/1.33G [00:33<00:02, 45.8MB/s]
#
#
#
#
# Downloading:  91%|██████████████████████████████████████████████████████████▏     | 1.21G/1.33G [00:33<00:02, 43.5MB/s]
#
#
#
#
# Downloading:  91%|██████████████████████████████████████████████████████████▎     | 1.21G/1.33G [00:33<00:02, 42.8MB/s]
#
#
#
#
# Downloading:  92%|██████████████████████████████████████████████████████████▌     | 1.22G/1.33G [00:33<00:03, 39.3MB/s]
#
#
#
#
# Downloading:  92%|██████████████████████████████████████████████████████████▋     | 1.22G/1.33G [00:33<00:03, 37.3MB/s]
#
#
#
#
# Downloading:  92%|██████████████████████████████████████████████████████████▉     | 1.22G/1.33G [00:33<00:03, 34.0MB/s]
#
#
#
#
# Downloading:  92%|███████████████████████████████████████████████████████████     | 1.23G/1.33G [00:34<00:03, 32.1MB/s]
#
#
#
#
# Downloading:  93%|███████████████████████████████████████████████████████████▏    | 1.23G/1.33G [00:34<00:04, 26.4MB/s]
#
#
#
#
# Downloading:  93%|███████████████████████████████████████████████████████████▎    | 1.23G/1.33G [00:34<00:04, 22.6MB/s]
#
#
#
#
# Downloading:  93%|███████████████████████████████████████████████████████████▍    | 1.23G/1.33G [00:34<00:04, 22.7MB/s]
#
#
#
#
# Downloading:  93%|███████████████████████████████████████████████████████████▌    | 1.24G/1.33G [00:34<00:04, 23.1MB/s]
#
#
#
#
# Downloading:  93%|███████████████████████████████████████████████████████████▋    | 1.24G/1.33G [00:34<00:03, 24.1MB/s]
#
#
#
#
# Downloading:  93%|███████████████████████████████████████████████████████████▊    | 1.24G/1.33G [00:34<00:03, 24.4MB/s]
#
#
#
#
# Downloading:  94%|███████████████████████████████████████████████████████████▉    | 1.24G/1.33G [00:34<00:03, 26.0MB/s]
#
#
#
#
# Downloading:  94%|████████████████████████████████████████████████████████████    | 1.25G/1.33G [00:34<00:03, 27.6MB/s]
#
#
#
#
# Downloading:  94%|████████████████████████████████████████████████████████████▎   | 1.25G/1.33G [00:35<00:02, 31.9MB/s]
#
#
#
#
# Downloading:  94%|████████████████████████████████████████████████████████████▍   | 1.25G/1.33G [00:35<00:02, 34.2MB/s]
#
#
#
#
# Downloading:  95%|████████████████████████████████████████████████████████████▌   | 1.26G/1.33G [00:35<00:02, 35.2MB/s]
#
#
#
#
# Downloading:  95%|████████████████████████████████████████████████████████████▊   | 1.26G/1.33G [00:35<00:02, 34.7MB/s]
#
#
#
#
# Downloading:  95%|████████████████████████████████████████████████████████████▉   | 1.26G/1.33G [00:35<00:01, 34.9MB/s]
#
#
#
#
# Downloading:  95%|█████████████████████████████████████████████████████████████   | 1.27G/1.33G [00:35<00:01, 35.7MB/s]
#
#
#
#
# Downloading:  96%|█████████████████████████████████████████████████████████████▎  | 1.27G/1.33G [00:35<00:01, 37.4MB/s]
#
#
#
#
# Downloading:  96%|█████████████████████████████████████████████████████████████▍  | 1.28G/1.33G [00:35<00:01, 37.8MB/s]
#
#
#
#
# Downloading:  96%|█████████████████████████████████████████████████████████████▋  | 1.28G/1.33G [00:35<00:01, 38.3MB/s]
#
#
#
#
# Downloading:  97%|█████████████████████████████████████████████████████████████▊  | 1.28G/1.33G [00:36<00:01, 40.8MB/s]
#
#
#
#
# Downloading:  97%|██████████████████████████████████████████████████████████████  | 1.29G/1.33G [00:36<00:01, 40.3MB/s]
#
#
#
#
# Downloading:  97%|██████████████████████████████████████████████████████████████▏ | 1.29G/1.33G [00:36<00:01, 39.4MB/s]
#
#
#
#
# Downloading:  98%|██████████████████████████████████████████████████████████████▍ | 1.29G/1.33G [00:36<00:00, 38.9MB/s]
#
#
#
#
# Downloading:  98%|██████████████████████████████████████████████████████████████▌ | 1.30G/1.33G [00:36<00:00, 37.1MB/s]
#
#
#
#
# Downloading:  98%|██████████████████████████████████████████████████████████████▋ | 1.30G/1.33G [00:36<00:00, 36.3MB/s]
# Downloading:  98%|██████████████████████████████████████████████████████████████▉ | 1.31G/1.33G [00:36<00:00, 36.2MB/s]
#
#
#
#
# Downloading:  99%|███████████████████████████████████████████████████████████████ | 1.31G/1.33G [00:36<00:00, 21.6MB/s]
#
#
#
#
# Downloading:  99%|███████████████████████████████████████████████████████████████▏| 1.31G/1.33G [00:37<00:00, 25.1MB/s]
#
#
#
#
# Downloading:  99%|███████████████████████████████████████████████████████████████▍| 1.32G/1.33G [00:37<00:00, 28.6MB/s]
#
#
#
#
# Downloading:  99%|███████████████████████████████████████████████████████████████▌| 1.32G/1.33G [00:37<00:00, 30.7MB/s]
#
#
#
#
# Downloading: 100%|███████████████████████████████████████████████████████████████▊| 1.32G/1.33G [00:37<00:00, 29.8MB/s]
#
#
#
#
# Downloading: 100%|████████████████████████████████████████████████████████████████| 1.33G/1.33G [00:37<00:00, 38.0MB/s]
#
#
#
#
#   0%|▏                                                                               | 1/439 [01:09<8:25:37, 69.26s/it]
#
#
#
#   0%|▎                                                                               | 2/439 [01:28<4:52:09, 40.11s/it]
#
#
#
#   1%|▌                                                                               | 3/439 [01:46<3:37:58, 30.00s/it]
#
#
#
#   1%|▋                                                                               | 4/439 [02:05<3:05:54, 25.64s/it]
#
#
#
#   1%|▉                                                                               | 5/439 [02:23<2:44:42, 22.77s/it]
#
#
#
#   1%|█                                                                               | 6/439 [02:36<2:19:37, 19.35s/it]
#
#
#
#   2%|█▎                                                                              | 7/439 [02:55<2:18:39, 19.26s/it]
#
#
#
#   2%|█▍                                                                              | 8/439 [03:13<2:15:38, 18.88s/it]
#
#
#
#   2%|█▋                                                                              | 9/439 [03:30<2:11:57, 18.41s/it]
#
#
#
#   2%|█▊                                                                             | 10/439 [03:47<2:08:44, 18.01s/it]
#
#
#
#   3%|█▉                                                                             | 11/439 [04:05<2:07:19, 17.85s/it]
#
#
#
#   3%|██▏                                                                            | 12/439 [04:24<2:09:35, 18.21s/it]
#
#
#
#   3%|██▎                                                                            | 13/439 [04:41<2:05:55, 17.74s/it]
#
#
#
#   3%|██▌                                                                            | 14/439 [04:56<2:01:28, 17.15s/it]
#
#
#
#   3%|██▋                                                                            | 15/439 [05:11<1:56:14, 16.45s/it]
#
#
#
#   4%|██▉                                                                            | 16/439 [05:29<1:58:24, 16.80s/it]
#
#
#
#   4%|███                                                                            | 17/439 [05:48<2:03:34, 17.57s/it]
#
#
#
#   4%|███▏                                                                           | 18/439 [06:06<2:03:32, 17.61s/it]
#
#
#
#   4%|███▍                                                                           | 19/439 [06:25<2:05:50, 17.98s/it]
#
#
#
#   5%|███▌                                                                           | 20/439 [06:43<2:06:42, 18.15s/it]
#
#
#
#   5%|███▊                                                                           | 21/439 [07:02<2:07:23, 18.29s/it]
#
#
#
#   5%|███▉                                                                           | 22/439 [07:20<2:07:26, 18.34s/it]
#
#
#
#   5%|████▏                                                                          | 23/439 [07:35<1:59:07, 17.18s/it]
#
#
#
#   5%|████▎                                                                          | 24/439 [07:54<2:02:13, 17.67s/it]
#
#
#
#   6%|████▍                                                                          | 25/439 [08:10<1:58:58, 17.24s/it]
#
#
#
#   6%|████▋                                                                          | 26/439 [08:26<1:57:03, 17.01s/it]
#
#
#
#   6%|████▊                                                                          | 27/439 [08:45<2:00:10, 17.50s/it]
#
#
#
#   6%|█████                                                                          | 28/439 [09:03<2:01:12, 17.69s/it]
#
#
#
#   7%|█████▏                                                                         | 29/439 [09:22<2:03:13, 18.03s/it]
#
#
#
#   7%|█████▍                                                                         | 30/439 [09:41<2:04:27, 18.26s/it]
#
#
#
#   7%|█████▌                                                                         | 31/439 [10:01<2:07:21, 18.73s/it]
#
#
#
#   7%|█████▊                                                                         | 32/439 [10:18<2:05:23, 18.48s/it]
#
#
#
# ...
#
#
#
#  71%|███████████████████████████████████████████████████████                       | 310/439 [1:31:22<40:17, 18.74s/it]
#
#
#
#  71%|███████████████████████████████████████████████████████▎                      | 311/439 [1:31:41<39:45, 18.63s/it]
#
#
#
#  71%|███████████████████████████████████████████████████████▍                      | 312/439 [1:31:54<36:20, 17.17s/it]
#
#
#
#  71%|███████████████████████████████████████████████████████▌                      | 313/439 [1:32:13<37:02, 17.64s/it]
#
#
#
#  72%|███████████████████████████████████████████████████████▊                      | 314/439 [1:32:32<37:26, 17.97s/it]
#
#
#
#  72%|███████████████████████████████████████████████████████▉                      | 315/439 [1:32:50<37:16, 18.04s/it]
#
#
#
#  72%|████████████████████████████████████████████████████████▏                     | 316/439 [1:33:09<37:45, 18.42s/it]
#
#
#
#  72%|████████████████████████████████████████████████████████▎                     | 317/439 [1:33:24<35:19, 17.38s/it]
#
#
#
#  72%|████████████████████████████████████████████████████████▌                     | 318/439 [1:33:41<34:49, 17.27s/it]
#
#
#
#  73%|████████████████████████████████████████████████████████▋                     | 319/439 [1:33:45<26:34, 13.29s/it]
#
#
#
#  73%|████████████████████████████████████████████████████████▊                     | 320/439 [1:34:04<29:22, 14.81s/it]
#
#
#
#  73%|█████████████████████████████████████████████████████████                     | 321/439 [1:34:22<31:14, 15.88s/it]
#
#
#
#  73%|█████████████████████████████████████████████████████████▏                    | 322/439 [1:34:41<32:31, 16.68s/it]
#
#
#
#  74%|█████████████████████████████████████████████████████████▍                    | 323/439 [1:34:59<33:15, 17.20s/it]
#
#
#
#  74%|█████████████████████████████████████████████████████████▌                    | 324/439 [1:35:15<32:13, 16.81s/it]
#
#
#
#  74%|█████████████████████████████████████████████████████████▋                    | 325/439 [1:35:32<32:16, 16.99s/it]
#
#
#
#  74%|█████████████████████████████████████████████████████████▉                    | 326/439 [1:35:51<33:13, 17.64s/it]
#
#
#
#  74%|██████████████████████████████████████████████████████████                    | 327/439 [1:36:09<33:04, 17.72s/it]
#
#
#
#  75%|██████████████████████████████████████████████████████████▎                   | 328/439 [1:36:28<33:03, 17.87s/it]
#
#
#
#  75%|██████████████████████████████████████████████████████████▍                   | 329/439 [1:36:45<32:35, 17.78s/it]
#
#
#
#  75%|██████████████████████████████████████████████████████████▋                   | 330/439 [1:37:05<33:29, 18.43s/it]
#
#
#
#  75%|██████████████████████████████████████████████████████████▊                   | 331/439 [1:37:25<33:58, 18.87s/it]
#
#
#
#  76%|██████████████████████████████████████████████████████████▉                   | 332/439 [1:37:43<33:29, 18.78s/it]
#
#
#
#  76%|███████████████████████████████████████████████████████████▏                  | 333/439 [1:38:01<32:26, 18.36s/it]
#
#
#
#  76%|███████████████████████████████████████████████████████████▎                  | 334/439 [1:38:19<31:50, 18.19s/it]
#
#
#
#  76%|███████████████████████████████████████████████████████████▌                  | 335/439 [1:38:37<31:23, 18.11s/it]
#
#
#
#  77%|███████████████████████████████████████████████████████████▋                  | 336/439 [1:38:55<31:17, 18.23s/it]
#
#
#
#  77%|███████████████████████████████████████████████████████████▉                  | 337/439 [1:39:14<31:28, 18.51s/it]
#
#
#
#  77%|████████████████████████████████████████████████████████████                  | 338/439 [1:39:34<31:31, 18.73s/it]
#
#
#
#  77%|████████████████████████████████████████████████████████████▏                 | 339/439 [1:39:50<29:59, 17.99s/it]
#
#
#
#  77%|████████████████████████████████████████████████████████████▍                 | 340/439 [1:40:08<29:58, 18.17s/it]
#
#
#
#  78%|████████████████████████████████████████████████████████████▌                 | 341/439 [1:40:21<27:10, 16.64s/it]
#
#
#
#  78%|████████████████████████████████████████████████████████████▊                 | 342/439 [1:40:40<27:46, 17.18s/it]
#
#
#
#  78%|████████████████████████████████████████████████████████████▉                 | 343/439 [1:40:59<28:26, 17.77s/it]
#
#
#
#  78%|█████████████████████████████████████████████████████████████                 | 344/439 [1:41:12<25:42, 16.24s/it]
#
#
#
#  79%|█████████████████████████████████████████████████████████████▎                | 345/439 [1:41:30<26:20, 16.81s/it]
#
#
#
#  79%|█████████████████████████████████████████████████████████████▍                | 346/439 [1:41:49<26:55, 17.37s/it]
#
#
#
#  79%|█████████████████████████████████████████████████████████████▋                | 347/439 [1:42:07<27:16, 17.79s/it]
#
#
#
#  79%|█████████████████████████████████████████████████████████████▊                | 348/439 [1:42:25<27:04, 17.85s/it]
#
#
#
#  79%|██████████████████████████████████████████████████████████████                | 349/439 [1:42:44<27:20, 18.23s/it]
#
#
#
#  80%|██████████████████████████████████████████████████████████████▏               | 350/439 [1:43:02<26:58, 18.19s/it]
#
#
#
#  80%|██████████████████████████████████████████████████████████████▎               | 351/439 [1:43:21<26:48, 18.28s/it]
#
#
#
#  80%|██████████████████████████████████████████████████████████████▌               | 352/439 [1:43:40<26:53, 18.55s/it]
#  80%|██████████████████████████████████████████████████████████████▋               | 353/439 [1:43:58<26:15, 18.32s/it]
#
#
#
#  81%|██████████████████████████████████████████████████████████████▉               | 354/439 [1:44:16<26:02, 18.39s/it]
#
#
#
#  81%|███████████████████████████████████████████████████████████████               | 355/439 [1:44:35<25:49, 18.45s/it]
#
#
#
#  81%|███████████████████████████████████████████████████████████████▎              | 356/439 [1:44:53<25:15, 18.26s/it]
#
#
#
#  81%|███████████████████████████████████████████████████████████████▍              | 357/439 [1:45:11<24:42, 18.08s/it]
#
#
#
#  82%|███████████████████████████████████████████████████████████████▌              | 358/439 [1:45:28<24:20, 18.03s/it]
#
#
#
#  82%|███████████████████████████████████████████████████████████████▊              | 359/439 [1:45:47<24:15, 18.19s/it]
#
#
#
#  82%|███████████████████████████████████████████████████████████████▉              | 360/439 [1:46:05<23:50, 18.11s/it]
#
#
#
#  82%|████████████████████████████████████████████████████████████████▏             | 361/439 [1:46:22<23:04, 17.75s/it]
#
#
#
#  82%|████████████████████████████████████████████████████████████████▎             | 362/439 [1:46:38<22:14, 17.33s/it]
#
#
#
#  83%|████████████████████████████████████████████████████████████████▍             | 363/439 [1:46:54<21:31, 17.00s/it]
#
#
#
#  83%|████████████████████████████████████████████████████████████████▋             | 364/439 [1:47:13<21:48, 17.45s/it]
#
#
#
#  83%|████████████████████████████████████████████████████████████████▊             | 365/439 [1:47:31<21:35, 17.51s/it]
#
#
#
#  83%|█████████████████████████████████████████████████████████████████             | 366/439 [1:47:46<20:35, 16.92s/it]
#
#
#
#  84%|█████████████████████████████████████████████████████████████████▏            | 367/439 [1:48:05<21:00, 17.51s/it]
#
#
#
#  84%|█████████████████████████████████████████████████████████████████▍            | 368/439 [1:48:24<21:18, 18.01s/it]
#
#
#
#  84%|█████████████████████████████████████████████████████████████████▌            | 369/439 [1:48:42<20:57, 17.96s/it]
#
#
#
#  84%|█████████████████████████████████████████████████████████████████▋            | 370/439 [1:48:59<20:17, 17.65s/it]
#
#
#
#  85%|█████████████████████████████████████████████████████████████████▉            | 371/439 [1:49:17<20:01, 17.66s/it]
#
#
#
#  85%|██████████████████████████████████████████████████████████████████            | 372/439 [1:49:35<19:52, 17.80s/it]
#
#
#
#  85%|██████████████████████████████████████████████████████████████████▎           | 373/439 [1:49:53<19:45, 17.96s/it]
#
#
#
#  85%|██████████████████████████████████████████████████████████████████▍           | 374/439 [1:50:12<19:41, 18.18s/it]
#
#
#
#  85%|██████████████████████████████████████████████████████████████████▋           | 375/439 [1:50:29<19:09, 17.97s/it]
#
#
#
#  86%|██████████████████████████████████████████████████████████████████▊           | 376/439 [1:50:49<19:16, 18.35s/it]
#
#
#
#  86%|██████████████████████████████████████████████████████████████████▉           | 377/439 [1:51:07<19:00, 18.39s/it]
#
#
#
#  86%|███████████████████████████████████████████████████████████████████▏          | 378/439 [1:51:26<18:44, 18.43s/it]
#
#
#
#  86%|███████████████████████████████████████████████████████████████████▎          | 379/439 [1:51:44<18:23, 18.39s/it]
#
#
#
#  87%|███████████████████████████████████████████████████████████████████▌          | 380/439 [1:52:00<17:30, 17.80s/it]
#
#
#
#  87%|███████████████████████████████████████████████████████████████████▋          | 381/439 [1:52:19<17:23, 18.00s/it]
#
#
#
#  87%|███████████████████████████████████████████████████████████████████▊          | 382/439 [1:52:36<16:47, 17.67s/it]
#
#
#
#  87%|████████████████████████████████████████████████████████████████████          | 383/439 [1:52:53<16:21, 17.53s/it]
#
#
#
#  87%|████████████████████████████████████████████████████████████████████▏         | 384/439 [1:53:11<16:07, 17.59s/it]
#
#
#
#  88%|████████████████████████████████████████████████████████████████████▍         | 385/439 [1:53:29<15:57, 17.73s/it]
#
#
#
#  88%|████████████████████████████████████████████████████████████████████▌         | 386/439 [1:53:47<15:44, 17.83s/it]
#
#
#
#  88%|████████████████████████████████████████████████████████████████████▊         | 387/439 [1:54:05<15:31, 17.91s/it]
#
#
#
#  88%|████████████████████████████████████████████████████████████████████▉         | 388/439 [1:54:22<15:05, 17.75s/it]
#
#
#
#  89%|█████████████████████████████████████████████████████████████████████         | 389/439 [1:54:41<15:08, 18.17s/it]
#
#
#
#  89%|█████████████████████████████████████████████████████████████████████▎        | 390/439 [1:54:58<14:34, 17.84s/it]
#
#
#
#  89%|█████████████████████████████████████████████████████████████████████▍        | 391/439 [1:55:14<13:47, 17.24s/it]
#
#
#
#  89%|█████████████████████████████████████████████████████████████████████▋        | 392/439 [1:55:32<13:40, 17.46s/it]
#
#
#
#  90%|█████████████████████████████████████████████████████████████████████▊        | 393/439 [1:55:51<13:36, 17.76s/it]
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████        | 394/439 [1:56:04<12:23, 16.52s/it]
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████▏       | 395/439 [1:56:21<12:15, 16.71s/it]
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████▎       | 396/439 [1:56:39<12:13, 17.06s/it]
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████▌       | 397/439 [1:56:57<11:58, 17.12s/it]
#
#
#
#  91%|██████████████████████████████████████████████████████████████████████▋       | 398/439 [1:57:15<11:52, 17.37s/it]
#
#
#
#  91%|██████████████████████████████████████████████████████████████████████▉       | 399/439 [1:57:33<11:46, 17.65s/it]
#
#
#
#  91%|███████████████████████████████████████████████████████████████████████       | 400/439 [1:57:49<11:15, 17.32s/it]
#
#
#
#  91%|███████████████████████████████████████████████████████████████████████▏      | 401/439 [1:58:06<10:51, 17.15s/it]
#
#
#
#  92%|███████████████████████████████████████████████████████████████████████▍      | 402/439 [1:58:25<10:54, 17.68s/it]
#
#
#
#  92%|███████████████████████████████████████████████████████████████████████▌      | 403/439 [1:58:43<10:43, 17.87s/it]
#
#
#
#  92%|███████████████████████████████████████████████████████████████████████▊      | 404/439 [1:58:57<09:44, 16.69s/it]
#
#
#
#  92%|███████████████████████████████████████████████████████████████████████▉      | 405/439 [1:59:15<09:39, 17.05s/it]
#
#
#
#  92%|████████████████████████████████████████████████████████████████████████▏     | 406/439 [1:59:34<09:39, 17.58s/it]
#
#
#
#  93%|████████████████████████████████████████████████████████████████████████▎     | 407/439 [1:59:50<09:07, 17.11s/it]
#
#
#
#  93%|████████████████████████████████████████████████████████████████████████▍     | 408/439 [2:00:06<08:37, 16.70s/it]
#
#
#
#  93%|████████████████████████████████████████████████████████████████████████▋     | 409/439 [2:00:24<08:30, 17.03s/it]
#
#
#
#  93%|████████████████████████████████████████████████████████████████████████▊     | 410/439 [2:00:41<08:20, 17.26s/it]
#
#
#
#  94%|█████████████████████████████████████████████████████████████████████████     | 411/439 [2:00:57<07:51, 16.83s/it]
#
#
#
#  94%|█████████████████████████████████████████████████████████████████████████▏    | 412/439 [2:01:16<07:52, 17.50s/it]
#
#
#
#  94%|█████████████████████████████████████████████████████████████████████████▍    | 413/439 [2:01:34<07:38, 17.65s/it]
#
#
#
#  94%|█████████████████████████████████████████████████████████████████████████▌    | 414/439 [2:01:51<07:17, 17.52s/it]
#
#
#
#  95%|█████████████████████████████████████████████████████████████████████████▋    | 415/439 [2:02:09<06:59, 17.47s/it]
#
#
#
#  95%|█████████████████████████████████████████████████████████████████████████▉    | 416/439 [2:02:27<06:46, 17.67s/it]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████    | 417/439 [2:02:38<05:46, 15.76s/it]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 418/439 [2:02:57<05:52, 16.76s/it]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▍   | 419/439 [2:03:14<05:36, 16.81s/it]
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▌   | 420/439 [2:03:32<05:25, 17.12s/it]
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▊   | 421/439 [2:03:49<05:07, 17.08s/it]
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▉   | 422/439 [2:04:06<04:49, 17.05s/it]
#
#
#
#  96%|███████████████████████████████████████████████████████████████████████████▏  | 423/439 [2:04:24<04:37, 17.36s/it]
#
#
#
#  97%|███████████████████████████████████████████████████████████████████████████▎  | 424/439 [2:04:39<04:10, 16.73s/it]
#
#
#
#  97%|███████████████████████████████████████████████████████████████████████████▌  | 425/439 [2:04:56<03:53, 16.68s/it]
#
#
#
#  97%|███████████████████████████████████████████████████████████████████████████▋  | 426/439 [2:05:13<03:36, 16.67s/it]
#
#
#
#  97%|███████████████████████████████████████████████████████████████████████████▊  | 427/439 [2:05:30<03:23, 16.92s/it]
#
#
#
#  97%|████████████████████████████████████████████████████████████████████████████  | 428/439 [2:05:45<02:58, 16.21s/it]
#
#
#
#  98%|████████████████████████████████████████████████████████████████████████████▏ | 429/439 [2:06:03<02:47, 16.78s/it]
#
#
#
#  98%|████████████████████████████████████████████████████████████████████████████▍ | 430/439 [2:06:21<02:34, 17.22s/it]
#
#
#
#  98%|████████████████████████████████████████████████████████████████████████████▌ | 431/439 [2:06:40<02:21, 17.75s/it]
#
#
#
#  98%|████████████████████████████████████████████████████████████████████████████▊ | 432/439 [2:06:58<02:05, 17.89s/it]
#
#
#
#  99%|████████████████████████████████████████████████████████████████████████████▉ | 433/439 [2:07:16<01:47, 17.97s/it]
#
#
#
#  99%|█████████████████████████████████████████████████████████████████████████████ | 434/439 [2:07:35<01:30, 18.20s/it]
#
#
#
#  99%|█████████████████████████████████████████████████████████████████████████████▎| 435/439 [2:07:53<01:12, 18.04s/it]
#
#
#
#  99%|█████████████████████████████████████████████████████████████████████████████▍| 436/439 [2:08:09<00:52, 17.57s/it]
#
#
#
# 100%|█████████████████████████████████████████████████████████████████████████████▋| 437/439 [2:08:26<00:34, 17.37s/it]
#
#
#
# 100%|█████████████████████████████████████████████████████████████████████████████▊| 438/439 [2:08:44<00:17, 17.43s/it]
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████| 439/439 [2:09:04<00:00, 17.64s/it]

# %%
print(bleu_score, rouge_score, bert_precision, bert_recall, bert_f1)
# Out:
# nan nan nan nan nan
